# %% [markdown]
# # EUSTX Equity Curves + Performance (Python)
#
# - Includes: Buy & Hold, Momentum Top-20, Equal-Weight Monthly, Markowitz Min Variance, RL agents
# - Computes `IR3 = ARC^3 / (ASD * MD * MLD)`
# - Saves 3 panel plots into `output/EUSTX`
# - Prints LaTeX-ready panel table

# %%
from pathlib import Path
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# High-quality vector PDF output settings
plt.rcParams["pdf.fonttype"] = 42
plt.rcParams["ps.fonttype"] = 42
plt.rcParams["savefig.dpi"] = 600

MARKET = "EUSTX"
DATASET_FOLDER = "EUSTX"
ANNUALIZATION = 252

PANELS = {
    "Panel A: RL with LSTM and Cash Allowed": {
        "rl_runs": {"LSTM_1": "EUSTX_LSTM_DAILY_1", "LSTM_2": "EUSTX_LSTM_DAILY_2"},
        "plot_file": "fig_1-1.pdf",
    },
    "Panel B: RL with LSTM and Cash Not-Allowed": {
        "rl_runs": {"LSTM_NC_1": "EUSTX_LSTM_NC_DAILY", "LSTM_NC_2": "EUSTX_LSTM_NC_DAILY_2"},
        "plot_file": "fig_2-1.pdf",
    },
    "Panel C: RL with Transformers": {
        "rl_runs": {"TRANSFORMERS": "EUSTX_TRANSFORMERS_DAILY_1"},
        "plot_file": "fig_3-1.pdf",
    },
}

BASELINE_RUN = "EUSTX_LSTM_DAILY_1"
BASELINE_STRATEGIES = {
    "Buy & Hold": "QQQ Buy-and-Hold",
    "Momentum Top-20": "Momentum Top-20%",
    "Equal-Weight Monthly": "Equal-Weight Monthly",
}
MARKOWITZ_LABEL = "Markowitz Min Variance"
MARKOWITZ_COL = "EUSTX_Min Variance"

PLOT_COLORS = {
    "Buy & Hold": "black",
    "Momentum Top-20": "darkgreen",
    "Equal-Weight Monthly": "dodgerblue",
    MARKOWITZ_LABEL: "orange",
    "LSTM_1": "darkred",
    "LSTM_2": "purple",
    "LSTM_NC_1": "darkred",
    "LSTM_NC_2": "purple",
    "TRANSFORMERS": "darkred",
}


def find_repo_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / ".git").exists() and (candidate / "Results_Daily").exists():
            return candidate
    raise FileNotFoundError("Could not locate repository root.")


REPO_ROOT = find_repo_root(Path.cwd().resolve())
RESULTS_ROOT = REPO_ROOT / "Results_Daily" / MARKET
MARKOWITZ_FILE = REPO_ROOT / "v1_Changes_Calculations" / "Benchmark_Markowitz" / "markowitz_daily_returns_EUSTX.csv"
OUT_DIR = REPO_ROOT / "v1_Changes_Calculations" / "New_Equity_Curves_Performance" / "output" / "EUSTX"
OUT_DIR.mkdir(parents=True, exist_ok=True)


def load_returns(run_folder: str, file_name: str) -> pd.DataFrame:
    p = RESULTS_ROOT / run_folder / file_name
    df = pd.read_csv(p)
    if "date" not in df.columns:
        df = df.rename(columns={df.columns[0]: "date"})
    df["date"] = pd.to_datetime(df["date"])
    return df.sort_values("date")


def load_rl_series(run_folder: str) -> pd.Series:
    return load_returns(run_folder, "rl_daily_returns_oos.csv").set_index("date")["RL Agent"]


def load_baseline_series() -> dict:
    df = load_returns(BASELINE_RUN, "daily_returns_oos.csv").set_index("date")
    out = {}
    for nice, raw in BASELINE_STRATEGIES.items():
        out[nice] = df[raw]
    return out


def load_markowitz_series() -> pd.Series:
    df = pd.read_csv(MARKOWITZ_FILE)
    df["date"] = pd.to_datetime(df["date"])
    return df.set_index("date")[MARKOWITZ_COL]


def load_baseline_adt() -> dict:
    df = pd.read_csv(RESULTS_ROOT / BASELINE_RUN / "performance_metrics_oos.csv")
    m = dict(zip(df["Strategy"], df["Avg Daily Turnover (%)"]))
    return {nice: float(m.get(raw, np.nan)) for nice, raw in BASELINE_STRATEGIES.items()}


def load_rl_adt(run_folder: str) -> float:
    df = pd.read_csv(RESULTS_ROOT / run_folder / "rl_performance_metrics.csv")
    if "Unnamed: 0" in df.columns:
        df = df.rename(columns={"Unnamed: 0": "Strategy"})
    row = df.loc[df["Strategy"] == "RL Agent"]
    return float(row["Avg Daily Turnover (%)"].iloc[0]) if not row.empty else np.nan


def estimate_markowitz_adt_pct_from_tc_diff(tc_bps: float = 2.0, variant: str = "min_variance") -> float:
    import sys

    code_dir = REPO_ROOT / "Code"
    mkz_dir = REPO_ROOT / "v1_Changes_Calculations" / "Benchmark_Markowitz"
    if str(code_dir) not in sys.path:
        sys.path.insert(0, str(code_dir))
    if str(mkz_dir) not in sys.path:
        sys.path.insert(0, str(mkz_dir))

    from functions.data_pipeline_daily import build_dataset
    from markowitz import run_markowitz_wfo

    dataset = build_dataset(str(REPO_ROOT / "Data" / DATASET_FOLDER / "Outputs" / "Data"))
    kwargs = dict(
        variant=variant,
        train_months=60,
        val_months=12,
        test_months=12,
        step_months=12,
        rebalance_freq_days=21,
        max_weight=0.10,
        top_k=20,
        annualization=ANNUALIZATION,
        verbose=False,
    )
    r0 = run_markowitz_wfo(dataset, transaction_cost_bps=0.0, **kwargs)["daily_returns"]
    rt = run_markowitz_wfo(dataset, transaction_cost_bps=tc_bps, **kwargs)["daily_returns"]

    idx = r0.index.intersection(rt.index)
    if len(idx) == 0:
        return np.nan
    tc_rate = tc_bps / 10_000.0
    implied_turnover = ((r0.loc[idx] - rt.loc[idx]) / tc_rate).clip(lower=0)
    return float(implied_turnover.mean() * 100.0)


def equity_to_returns(tab):
    tab = np.asarray(tab, dtype=float)
    return (tab[1:] / tab[:-1]) - 1.0


def absolute_return(tab):
    ret = equity_to_returns(tab)
    return float((np.prod(1.0 + ret) - 1.0) * 100.0) if len(ret) else 0.0


def arc(tab, annualization=252):
    tab = np.asarray(tab, dtype=float)
    ret = equity_to_returns(tab)
    if len(tab) <= 1:
        return 0.0
    a_rtn = np.prod(1.0 + ret[:-1]) if len(ret) > 1 else 1.0
    if a_rtn <= 0:
        return 0.0
    return float(100.0 * (math.pow(a_rtn, annualization / len(tab)) - 1.0))


def asd(tab, annualization=252):
    ret = equity_to_returns(tab)
    return float(np.sqrt(annualization) * np.std(ret) * 100.0) if len(ret) else 0.0


def mdd(tab):
    ret = equity_to_returns(tab)
    if len(ret) == 0:
        return 0.0
    cum = np.cumprod(1.0 + ret)
    cmax = np.maximum.accumulate(cum)
    dd = (cmax - cum) / cmax
    return float(np.max(dd) * 100.0)


def mld(tab, annualization=252):
    temp = np.asarray(tab, dtype=float)
    if len(temp) == 0:
        return 1.0
    i = int(np.argmax(np.maximum.accumulate(temp) - temp))
    if i == 0:
        return len(temp) / annualization
    j = int(np.argmax(temp[:i]))
    mld_end = -1
    for k in range(i, len(temp)):
        if (temp[k - 1] < temp[j]) and (temp[j] < temp[k]):
            mld_end = k
            break
    if mld_end == -1:
        mld_end = len(temp)
    return float(abs(mld_end - j) / annualization)


def ir1(arc_v, asd_v):
    return float(max(arc_v / asd_v, 0.0)) if asd_v != 0 else 0.0


def ir2(arc_v, asd_v, mdd_v):
    denom = asd_v * mdd_v
    if denom == 0:
        return 0.0
    numer = (arc_v ** 2) * (0 if arc_v == 0 else int(abs(arc_v) / arc_v))
    return float(max(numer / denom, 0.0))


def ir3(arc_v, asd_v, mdd_v, mld_v):
    denom = asd_v * mdd_v * mld_v
    if denom == 0:
        return 0.0
    return float((arc_v ** 3) / denom)


def sharpe_from_returns(r, annualization=252):
    if len(r) <= 1 or np.std(r) <= 1e-12:
        return 0.0
    return float(np.mean(r) / np.std(r) * np.sqrt(annualization))


def compute_metrics_from_returns(returns: pd.Series, adt=np.nan):
    r = returns.dropna().to_numpy(dtype=float)
    eq = np.concatenate(([1.0], np.cumprod(1.0 + r)))
    ar_v = absolute_return(eq)
    arc_v = arc(eq, ANNUALIZATION)
    asd_v = asd(eq, ANNUALIZATION)
    md_v = mdd(eq)
    mld_v = mld(eq, ANNUALIZATION)
    return {
        "AR (%)": ar_v,
        "ARC (%)": arc_v,
        "ASD (%)": asd_v,
        "MD (%)": md_v,
        "MLD": mld_v,
        "IR1": ir1(arc_v, asd_v) * 100.0,
        "IR2": ir2(arc_v, asd_v, md_v) * 100.0,
        "IR3": ir3(arc_v, asd_v, md_v, mld_v),
        "Sharpe": sharpe_from_returns(r, ANNUALIZATION),
        "ADT": float(adt) if pd.notna(adt) else np.nan,
    }


def make_equity(returns: pd.Series) -> pd.Series:
    s = returns.dropna().sort_index()
    return (1.0 + s).cumprod()


baseline_series = load_baseline_series()
baseline_adt = load_baseline_adt()
markowitz_series = load_markowitz_series()
markowitz_adt_pct = estimate_markowitz_adt_pct_from_tc_diff(tc_bps=2.0, variant="min_variance")
print(f"Estimated {MARKOWITZ_LABEL} ADT (%): {markowitz_adt_pct:.3f}")


def collect_panel_series(panel_cfg):
    sdict = {
        "Buy & Hold": baseline_series["Buy & Hold"],
        "Momentum Top-20": baseline_series["Momentum Top-20"],
        "Equal-Weight Monthly": baseline_series["Equal-Weight Monthly"],
        MARKOWITZ_LABEL: markowitz_series,
    }
    for rl_label, run_folder in panel_cfg["rl_runs"].items():
        sdict[rl_label] = load_rl_series(run_folder)
    return sdict


panel_aligned = {}
global_ymax = -np.inf
global_ymin = np.inf

for panel_name, panel_cfg in PANELS.items():
    aligned = pd.concat(collect_panel_series(panel_cfg), axis=1, join="inner").dropna()
    panel_aligned[panel_name] = aligned
    for col in aligned.columns:
        eq = make_equity(aligned[col])
        if len(eq):
            global_ymax = max(global_ymax, float(eq.max()))
            global_ymin = min(global_ymin, float(eq.min()))

if not np.isfinite(global_ymax):
    global_ymax = 1.0
if not np.isfinite(global_ymin):
    global_ymin = 0.0

for panel_name, panel_cfg in PANELS.items():
    aligned = panel_aligned[panel_name]
    fig, ax = plt.subplots(figsize=(12, 6))
    for col in aligned.columns:
        eq = make_equity(aligned[col])
        ax.plot(eq.index, eq.values, label=col, color=PLOT_COLORS.get(col, None), linewidth=1.6)

    ax.set_title(panel_name, fontsize=13)
    ax.set_xlabel("Date")
    ax.set_ylabel("Equity")
    ax.set_ylim(bottom=global_ymin, top=global_ymax)
    ax.grid(True, alpha=0.3)
    ax.legend(loc="upper left", frameon=True, fontsize=9)
    fig.tight_layout()

    out_path = OUT_DIR / panel_cfg["plot_file"]
    fig.savefig(out_path, dpi=600, bbox_inches="tight", facecolor="white", metadata={"Creator": "Matplotlib"})
    plt.show()
    print(f"Saved plot: {out_path}")


metric_dirs = {
    "AR (%)": "max",
    "ARC (%)": "max",
    "ASD (%)": "min",
    "MD (%)": "min",
    "MLD": "min",
    "IR1": "max",
    "IR2": "max",
    "IR3": "max",
    "Sharpe": "max",
    "ADT": "min",
}
metric_cols = ["AR (%)", "ARC (%)", "ASD (%)", "MD (%)", "MLD", "IR1", "IR2", "IR3", "Sharpe", "ADT"]


def pick_best_mask(values: pd.Series, direction: str, ignore_zeros: bool = False) -> pd.Series:
    x = pd.to_numeric(values, errors="coerce")
    work = x[(x != 0) & x.notna()] if ignore_zeros else x.copy()
    if work.empty:
        return pd.Series(False, index=values.index)
    best = work.max() if direction == "max" else work.min()
    return x.eq(best)


def fmt_value(col: str, v: float) -> str:
    if pd.isna(v):
        return "-"
    if col == "AR (%)":
        return f"{v:.1f}"
    if col in {"ARC (%)", "ASD (%)", "MD (%)"}:
        return f"{v:.2f}"
    if col == "MLD":
        return f"{v:.3f}"
    if col in {"IR1", "IR2", "IR3", "Sharpe"}:
        return f"{v:.4f}"
    if col == "ADT":
        return f"{v:.3f}"
    return f"{v:.4f}"


def build_panel_perf(panel_name, panel_cfg):
    rows = []
    for strat in ["Buy & Hold", "Momentum Top-20", "Equal-Weight Monthly"]:
        rows.append({"Panel": panel_name, "Strategy": strat, **compute_metrics_from_returns(baseline_series[strat], adt=baseline_adt.get(strat, np.nan))})

    rows.append({"Panel": panel_name, "Strategy": MARKOWITZ_LABEL, **compute_metrics_from_returns(markowitz_series, adt=markowitz_adt_pct)})

    for rl_label, run_folder in panel_cfg["rl_runs"].items():
        rows.append({"Panel": panel_name, "Strategy": rl_label, **compute_metrics_from_returns(load_rl_series(run_folder), adt=load_rl_adt(run_folder))})

    return pd.DataFrame(rows)


perf = pd.concat([build_panel_perf(name, cfg) for name, cfg in PANELS.items()], ignore_index=True)
print("\nNumeric performance table with IR3")
display(perf)


lines = []
lines.append(r"\begin{table}[htbp]")
lines.append(r"\centering")
lines.append(r"\scriptsize")
lines.append(r"\setlength{\tabcolsep}{3pt}")
lines.append(r"\renewcommand{\arraystretch}{0.95}")
lines.append(r"\resizebox{\textwidth}{!}{%")
lines.append(r"\begin{tabular}{lcccccccccc}")
lines.append("")
lines.append(r"\toprule")
lines.append(r"\textbf{Strategy} & \textbf{AR (\%)} & \textbf{ARC (\%)} & \textbf{ASD (\%)} & \textbf{MD (\%)} & \textbf{MLD} & \textbf{IR1} & \textbf{IR2} & \textbf{IR3} & \textbf{Sharpe} & \textbf{ADT} \\")
lines.append(r"\midrule")

for p_name in PANELS.keys():
    p_df = perf.loc[perf["Panel"] == p_name].copy().reset_index(drop=True)
    lines.append("")
    lines.append(rf"\multicolumn{{11}}{{l}}{{\textbf{{{p_name}}}}} \\")
    lines.append(r"\midrule")

    best_masks = {mc: pick_best_mask(p_df[mc], metric_dirs[mc], ignore_zeros=(mc == "ADT")) for mc in metric_cols}

    for i, row in p_df.iterrows():
        strategy = str(row["Strategy"]).replace("&", r"\&").replace("_", r"\_")
        vals = []
        for mc in metric_cols:
            txt = fmt_value(mc, row[mc])
            if best_masks[mc].iloc[i] and txt != "-":
                txt = rf"\textbf{{{txt}}}"
            vals.append(txt)
        lines.append(strategy + " & " + " & ".join(vals) + r" \\")

    lines.append(r"\addlinespace")

lines.append(r"\bottomrule")
lines.append(r"\end{tabular}%")
lines.append(r"}")
lines.append(r"\end{table}")

latex_table = "\n".join(lines)
print("\nLaTeX table (copy/paste):\n")
print(latex_table)
print(f"\nAll plots saved under: {OUT_DIR}")
# Out:
# ============================================================
# DATA PIPELINE — RL Portfolio (DAILY REBALANCING)
# ============================================================
#
# [1/5] Loading raw data...
#   Risk-free rate loaded from: /Users/kamilkashif/Documents/University/Masters Thesis/MS-Thesis-Deep-RL-KK/Data/EUSTX/Outputs/Data/risk_free_data.csv
#   Prices: (5961, 79)
#   Mask:   (5961, 79)
#   QQQ:    (5836, 1)
#   VIX:    (5836, 1)
#
# [2/5] Cleaning & aligning (daily)...
#   Tickers:       79
#   Trading days:  5961
#   Date range:    2003-01-02 → 2026-03-13
#   Close coverage: 100.0% mean, 100.0% min
#
# [3/5] Building per-asset features (13 features)...
# /Users/kamilkashif/miniforge3/envs/RL_MS_Thesis/lib/python3.14/site-packages/pandas/core/internals/blocks.py:347: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# /Users/kamilkashif/miniforge3/envs/RL_MS_Thesis/lib/python3.14/site-packages/pandas/core/internals/blocks.py:347: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
#   Features per asset:  13
#   Feature names:       ['bb_pctb', 'beta_qqq', 'dist_high_20', 'macd_hist', 'mean_rev_20', 'raw_ret_20d', 'ret_1d', 'ret_20d', 'ret_5d', 'ret_60d', 'rsi_14', 'rvol_20d', 'rvol_5d']
#   Total columns:       1027
#
# [4/5] Building global features (9 features)...
#   Global features: ['vix_level', 'vix_change_5d', 'market_ret_1d', 'market_rvol_5d', 'dow', 'market_breadth', 'qqq_ret_5d', 'qqq_ret_20d', 'cross_disp']
#
# [5/5] Applying warmup period (60 days)...
#   Valid range:    2003-03-27 → 2026-03-13
#   Valid days:     5901
#   Per-asset NaN:  39.797%
#   Global NaN:     0.008%
#   Avg risk-free:  1.67% annualized
#
# ============================================================
# PIPELINE COMPLETE (DAILY MODE)
# ============================================================
# /Users/kamilkashif/miniforge3/envs/RL_MS_Thesis/lib/python3.14/site-packages/pandas/core/internals/blocks.py:347: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# /Users/kamilkashif/miniforge3/envs/RL_MS_Thesis/lib/python3.14/site-packages/pandas/core/internals/blocks.py:347: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Estimated Markowitz Min Variance ADT (%): 0.172
# Saved plot: /Users/kamilkashif/Documents/University/Masters Thesis/MS-Thesis-Deep-RL-KK/v1_Changes_Calculations/New_Equity_Curves_Performance/output/EUSTX/fig_1-1.pdf
# Saved plot: /Users/kamilkashif/Documents/University/Masters Thesis/MS-Thesis-Deep-RL-KK/v1_Changes_Calculations/New_Equity_Curves_Performance/output/EUSTX/fig_2-1.pdf
# Saved plot: /Users/kamilkashif/Documents/University/Masters Thesis/MS-Thesis-Deep-RL-KK/v1_Changes_Calculations/New_Equity_Curves_Performance/output/EUSTX/fig_3-1.pdf
#
# Numeric performance table with IR3
#                                          Panel                Strategy  \
# 0       Panel A: RL with LSTM and Cash Allowed              Buy & Hold
# 1       Panel A: RL with LSTM and Cash Allowed         Momentum Top-20
# 2       Panel A: RL with LSTM and Cash Allowed    Equal-Weight Monthly
# 3       Panel A: RL with LSTM and Cash Allowed  Markowitz Min Variance
# 4       Panel A: RL with LSTM and Cash Allowed                  LSTM_1
# 5       Panel A: RL with LSTM and Cash Allowed                  LSTM_2
# 6   Panel B: RL with LSTM and Cash Not-Allowed              Buy & Hold
# 7   Panel B: RL with LSTM and Cash Not-Allowed         Momentum Top-20
# 8   Panel B: RL with LSTM and Cash Not-Allowed    Equal-Weight Monthly
# 9   Panel B: RL with LSTM and Cash Not-Allowed  Markowitz Min Variance
# 10  Panel B: RL with LSTM and Cash Not-Allowed               LSTM_NC_1
# 11  Panel B: RL with LSTM and Cash Not-Allowed               LSTM_NC_2
# 12               Panel C: RL with Transformers              Buy & Hold
# 13               Panel C: RL with Transformers         Momentum Top-20
# 14               Panel C: RL with Transformers    Equal-Weight Monthly
# 15               Panel C: RL with Transformers  Markowitz Min Variance
# 16               Panel C: RL with Transformers            TRANSFORMERS
#
#         AR (%)    ARC (%)    ASD (%)     MD (%)       MLD        IR1  \
# 0   238.202768   7.807200  23.920375  39.687768  1.642857  32.638285
# 1   209.026719   7.224106  21.070098  33.369186  1.547619  34.286059
# 2   384.792015  10.235127  20.631354  39.397696  1.138889  49.609573
# 3   343.341664   9.112447  18.305951  36.236082  0.412698  49.778604
# 4   275.490790   8.547789  18.705407  33.520867  1.047619  45.696889
# 5   265.409890   8.357184  15.967581  29.935368  1.059524  52.338449
# 6   238.202768   7.807200  23.920375  39.687768  1.642857  32.638285
# 7   209.026719   7.224106  21.070098  33.369186  1.547619  34.286059
# 8   384.792015  10.235127  20.631354  39.397696  1.138889  49.609573
# 9   343.341664   9.112447  18.305951  36.236082  0.412698  49.778604
# 10  208.280908   7.234179  19.870309  34.489233  1.130952  36.406976
# 11  280.581086   8.636489  19.523231  34.495053  1.091270  44.236989
# 12  238.202768   7.807200  23.920375  39.687768  1.642857  32.638285
# 13  209.026719   7.224106  21.070098  33.369186  1.547619  34.286059
# 14  384.792015  10.235127  20.631354  39.397696  1.138889  49.609573
# 15  343.341664   9.112447  18.305951  36.236082  0.412698  49.778604
# 16  284.687224   8.709325  18.779836  33.161421  1.047619  46.375941
#
#           IR2       IR3    Sharpe        ADT
# 0    6.420458  0.305114  0.433331   0.000000
# 1    7.422600  0.346478  0.434780  39.183800
# 2   12.888070  1.158243  0.573820   0.859300
# 3   12.518044  2.764004  0.565256   0.172126
# 4   11.652663  0.950770  0.530126  10.613400
# 5   14.611548  1.152512  0.580653  11.415800
# 6    6.420458  0.305114  0.433331   0.000000
# 7    7.422600  0.346478  0.434780  39.183800
# 8   12.888070  1.158243  0.573820   0.859300
# 9   12.518044  2.764004  0.565256   0.172126
# 10   7.636429  0.488467  0.449190  15.661300
# 11  11.075568  0.876539  0.520223  12.696500
# 12   6.420458  0.305114  0.433331   0.000000
# 13   7.422600  0.346478  0.434780  39.183800
# 14  12.888070  1.158243  0.573820   0.859300
# 15  12.518044  2.764004  0.565256   0.172126
# 16  12.179911  1.012570  0.536706   8.418200
# LaTeX table (copy/paste):
#
# \begin{table}[htbp]
# \centering
# \scriptsize
# \setlength{\tabcolsep}{3pt}
# \renewcommand{\arraystretch}{0.95}
# \resizebox{\textwidth}{!}{%
# \begin{tabular}{lcccccccccc}
#
# \toprule
# \textbf{Strategy} & \textbf{AR (\%)} & \textbf{ARC (\%)} & \textbf{ASD (\%)} & \textbf{MD (\%)} & \textbf{MLD} & \textbf{IR1} & \textbf{IR2} & \textbf{IR3} & \textbf{Sharpe} & \textbf{ADT} \\
# \midrule
#
# \multicolumn{11}{l}{\textbf{Panel A: RL with LSTM and Cash Allowed}} \\
# \midrule
# Buy \& Hold & 238.2 & 7.81 & 23.92 & 39.69 & 1.643 & 32.6383 & 6.4205 & 0.3051 & 0.4333 & 0.000 \\
# Momentum Top-20 & 209.0 & 7.22 & 21.07 & 33.37 & 1.548 & 34.2861 & 7.4226 & 0.3465 & 0.4348 & 39.184 \\
# Equal-Weight Monthly & \textbf{384.8} & \textbf{10.24} & 20.63 & 39.40 & 1.139 & 49.6096 & 12.8881 & 1.1582 & 0.5738 & 0.859 \\
# Markowitz Min Variance & 343.3 & 9.11 & 18.31 & 36.24 & \textbf{0.413} & 49.7786 & 12.5180 & \textbf{2.7640} & 0.5653 & \textbf{0.172} \\
# LSTM\_1 & 275.5 & 8.55 & 18.71 & 33.52 & 1.048 & 45.6969 & 11.6527 & 0.9508 & 0.5301 & 10.613 \\
# LSTM\_2 & 265.4 & 8.36 & \textbf{15.97} & \textbf{29.94} & 1.060 & \textbf{52.3384} & \textbf{14.6115} & 1.1525 & \textbf{0.5807} & 11.416 \\
# \addlinespace
#
# \multicolumn{11}{l}{\textbf{Panel B: RL with LSTM and Cash Not-Allowed}} \\
# \midrule
# Buy \& Hold & 238.2 & 7.81 & 23.92 & 39.69 & 1.643 & 32.6383 & 6.4205 & 0.3051 & 0.4333 & 0.000 \\
# Momentum Top-20 & 209.0 & 7.22 & 21.07 & \textbf{33.37} & 1.548 & 34.2861 & 7.4226 & 0.3465 & 0.4348 & 39.184 \\
# Equal-Weight Monthly & \textbf{384.8} & \textbf{10.24} & 20.63 & 39.40 & 1.139 & 49.6096 & \textbf{12.8881} & 1.1582 & \textbf{0.5738} & 0.859 \\
# Markowitz Min Variance & 343.3 & 9.11 & \textbf{18.31} & 36.24 & \textbf{0.413} & \textbf{49.7786} & 12.5180 & \textbf{2.7640} & 0.5653 & \textbf{0.172} \\
# LSTM\_NC\_1 & 208.3 & 7.23 & 19.87 & 34.49 & 1.131 & 36.4070 & 7.6364 & 0.4885 & 0.4492 & 15.661 \\
# LSTM\_NC\_2 & 280.6 & 8.64 & 19.52 & 34.50 & 1.091 & 44.2370 & 11.0756 & 0.8765 & 0.5202 & 12.697 \\
# \addlinespace
#
# \multicolumn{11}{l}{\textbf{Panel C: RL with Transformers}} \\
# \midrule
# Buy \& Hold & 238.2 & 7.81 & 23.92 & 39.69 & 1.643 & 32.6383 & 6.4205 & 0.3051 & 0.4333 & 0.000 \\
# Momentum Top-20 & 209.0 & 7.22 & 21.07 & 33.37 & 1.548 & 34.2861 & 7.4226 & 0.3465 & 0.4348 & 39.184 \\
# Equal-Weight Monthly & \textbf{384.8} & \textbf{10.24} & 20.63 & 39.40 & 1.139 & 49.6096 & \textbf{12.8881} & 1.1582 & \textbf{0.5738} & 0.859 \\
# Markowitz Min Variance & 343.3 & 9.11 & \textbf{18.31} & 36.24 & \textbf{0.413} & \textbf{49.7786} & 12.5180 & \textbf{2.7640} & 0.5653 & \textbf{0.172} \\
# TRANSFORMERS & 284.7 & 8.71 & 18.78 & \textbf{33.16} & 1.048 & 46.3759 & 12.1799 & 1.0126 & 0.5367 & 8.418 \\
# \addlinespace
# \bottomrule
# \end{tabular}%
# }
# \end{table}
#
# All plots saved under: /Users/kamilkashif/Documents/University/Masters Thesis/MS-Thesis-Deep-RL-KK/v1_Changes_Calculations/New_Equity_Curves_Performance/output/EUSTX
